# %% [markdown]
# <a href="https://colab.research.google.com/github/catyfgza/data/blob/master/A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
path = '/content/drive/MyDrive/datasets/antropometria-dataset.csv'
path
# Out:
# '/content/drive/MyDrive/datasets/antropometria-dataset.csv'

# %%
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(path)
df
# Out:
#         folio  intp  entidad                         desc_ent  sexo  edad  \
# 0      210295     2       21                           PUEBLA     2    38
# 1      101655     3       10                          DURANGO     2    11
# 2       10287     6        1                   AGUASCALIENTES     2    18
# 3       91526     4        9                 DISTRITO FEDERAL     1    10
# 4      210939     3       21                           PUEBLA     2    19
# ...       ...   ...      ...                              ...   ...   ...
# 18635  300116     2       30  VERACRUZ DE IGNACIO DE LA LLAVE     2    73
# 18636   40253     1        4                         CAMPECHE     2    75
# 18637  301099     1       30  VERACRUZ DE IGNACIO DE LA LLAVE     1    86
# 18638  250801     1       25                          SINALOA     2    72
# 18639   11786     2        1                   AGUASCALIENTES     2    71
#
#        meses   peso  ropa   talla  ... hpresion tbrazo  htension  PrimaryLast  \
# ...

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
ndf= df.loc[:,['peso','talla','cintura','cadera','sistol','diastol']]
ndf
# Out:
#         peso   talla  cintura  cadera  sistol  diastol
# 0      73.70  146.40    98.70   106.0   63.25    53.25
# 1      35.65  145.10    64.00    75.0   70.00    50.00
# 2      54.80  162.00    67.60    94.3   70.50    41.00
# 3      33.40  146.50    60.60    72.2   71.00    64.00
# 4      97.95  161.00   113.00   127.0   72.00    53.50
# ...      ...     ...      ...     ...     ...      ...
# 18635  75.80  141.15    93.00   113.0  221.00    95.50
# 18636  69.40  144.80   103.05   113.7  222.25    78.00
# 18637  46.75  149.20    71.35    86.0  230.00    66.00
# 18638  59.05  142.50    99.95    94.8  235.00   100.00
# 18639  80.00  150.65   108.15   120.0  240.00   150.00
#
# [18640 rows x 6 columns]

# %%
sns.boxplot(x = df["peso"], 
            whis=(0, 100))

# %%
ndf=pd.pivot_table(data = df,index='desc_ent',values='peso',columns='sexo',aggfunc='median')
ndf
# Out:
# sexo                                   1        2
# desc_ent
# AGUASCALIENTES                   69.9500  63.7000
# BAJA CALIFORNIA                  70.6500  64.2000
# BAJA CALIFORNIA SUR              76.6500  68.5500
# CAMPECHE                         67.3500  62.3750
# CHIAPAS                          59.2000  56.0250
# CHIHUAHUA                        69.3000  64.6250
# COAHUILA DE ZARAGOZA             68.3000  67.3000
# COLIMA                           71.7000  66.0000
# DISTRITO FEDERAL                 69.0000  61.4500
# DURANGO                          70.3500  62.5000
# GUANAJUATO                       65.0625  60.3250
# GUERRERO                         60.5000  57.2000
# HIDALGO                          63.3000  57.9000
# JALISCO                          65.5875  63.3500
# MEXICO                           62.4500  56.9500
# MICHOACAN DE OCAMPO              67.6250  63.4000
# MORELOS                          65.2000  61.4500
# NAYARIT                          69.0500  63.7000
# ...

# %%
x = {'peso_median_1':[69.95,70.65,76.65]}
x
# Out:
# {'peso_median_1': [69.95, 70.65, 76.65]}

# %%
df2 = pd.DataFrame(data=x)
df2
# Out:
#    peso_median_1
# 0          69.95
# 1          70.65
# 2          76.65

# %%
sns.boxplot(x = df2["peso_median_1"])

# %%
df3=pd.pivot_table(data = df,index='desc_ent',values='cintura',columns='sexo')
df3
# Out:
# sexo                                     1          2
# desc_ent
# AGUASCALIENTES                   88.349338  87.968018
# BAJA CALIFORNIA                  90.115303  88.864786
# BAJA CALIFORNIA SUR              92.337778  89.851594
# CAMPECHE                         90.054852  88.053832
# CHIAPAS                          81.183468  84.461201
# CHIHUAHUA                        89.338113  90.230392
# COAHUILA DE ZARAGOZA             88.814047  90.844884
# COLIMA                           90.075665  89.742163
# DISTRITO FEDERAL                 89.420402  91.837721
# DURANGO                          89.363529  89.071656
# GUANAJUATO                       85.662621  89.099745
# GUERRERO                         83.778172  86.055735
# HIDALGO                          83.333508  85.650063
# JALISCO                          87.642080  89.857635
# MEXICO                           85.651309  85.227953
# MICHOACAN DE OCAMPO              87.639380  89.614608
# ...

# %%
plt.plot(df3)

# %%
df4=pd.pivot_table(data = df,index='desc_ent',values='peso',columns='sexo',aggfunc='sum')
df4
# Out:
# sexo                                     1          2
# desc_ent
# AGUASCALIENTES                   21135.585  22328.765
# BAJA CALIFORNIA                  18847.440  19768.100
# BAJA CALIFORNIA SUR              19721.425  18337.450
# CAMPECHE                         16263.565  19127.830
# CHIAPAS                          14474.575  20554.600
# CHIHUAHUA                        18256.550  20870.525
# COAHUILA DE ZARAGOZA             20593.055  21117.280
# COLIMA                           18672.705  22504.740
# DISTRITO FEDERAL                 12086.155  13440.600
# DURANGO                          17555.845  20930.010
# GUANAJUATO                       18852.320  23473.570
# GUERRERO                         16779.865  21616.245
# HIDALGO                          11793.860  19284.025
# JALISCO                          15159.285  20390.360
# MEXICO                           12059.800  15428.625
# MICHOACAN DE OCAMPO              17124.650  21750.450
# ...

# %%
df4.plot(kind='barh')

# %%
df5= df.loc[:,'cintura']
df5
# Out:
# 0         98.70
# 1         64.00
# 2         67.60
# 3         60.60
# 4        113.00
#           ...
# 18635     93.00
# 18636    103.05
# 18637     71.35
# 18638     99.95
# 18639    108.15
# Name: cintura, Length: 18640, dtype: float64

# %%
hist = df5.hist(bins=25)
